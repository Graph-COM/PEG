# %% [markdown]
# # Node classification example for PEG (cora)

# %% [markdown]
# # Download dataset and load the data

# %%
from torch_geometric.datasets import Planetoid
from torch_geometric.transforms import NormalizeFeatures
import torch

dataset = Planetoid(root='data/Planetoid', name='Cora', transform=NormalizeFeatures())

print()
print(f'Dataset: {dataset}:')
print('======================')
print(f'Number of graphs: {len(dataset)}')
print(f'Number of features: {dataset.num_features}')
print(f'Number of classes: {dataset.num_classes}')

data = dataset[0]  # Get the first graph object.

print()
print(data)
print('===========================================================================================================')

# Gather some statistics about the graph.
print(f'Number of nodes: {data.num_nodes}')
print(f'Number of edges: {data.num_edges}')
print(f'Average node degree: {data.num_edges / data.num_nodes:.2f}')
print(f'Number of training nodes: {data.train_mask.sum()}')
print(f'Training node label rate: {int(data.train_mask.sum()) / data.num_nodes:.2f}')
# Out:
# Dataset: Cora():
# ======================
# Number of graphs: 1
# Number of features: 1433
# Number of classes: 7
#
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708])
# ===========================================================================================================
# Number of nodes: 2708
# Number of edges: 10556
# Average node degree: 3.90
# Number of training nodes: 140
# Training node label rate: 0.05

# %%
from torch_geometric.utils import to_networkx
device = f'cuda:{1}' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# # Preprocessing: calculate positional encodings

# %%
import networkx as nx
import numpy as np
import scipy.sparse as sp
import dgl
def laplacian_positional_encoding(g, pos_enc_dim):
    """
        Graph positional encoding v/ Laplacian eigenvectors
    """

    # Laplacian
    A = g.adjacency_matrix_scipy(return_edge_ids=False).astype(float)
    N = sp.diags(dgl.backend.asnumpy(g.in_degrees()).clip(1) ** -0.5, dtype=float)
    L = sp.eye(g.number_of_nodes()) - N * A * N

    # Eigenvectors with scipy
    #EigVal, EigVec = sp.linalg.eigs(L, k=pos_enc_dim+1, which='SR')
    EigVal, EigVec = sp.linalg.eigs(L, k=pos_enc_dim+1, which='SR', tol=1e-2) # for 40 PEs
    EigVec = EigVec[:, EigVal.argsort()] # increasing order
    out = torch.from_numpy(EigVec[:,1:pos_enc_dim+1]).float() 

    return out
# Out:
# Using backend: pytorch

# %%
PE_dim = 128
G = to_networkx(data)
adj = nx.to_numpy_array(G)
sp_adj = sp.coo_matrix(adj)
g = dgl.from_scipy(sp_adj)
embeddings = np.array(laplacian_positional_encoding(g, PE_dim))
# Out:
# /scratch1/wang5386/py2021/lib/python3.7/site-packages/dgl/base.py:45: DGLWarning: DGLGraph.adjacency_matrix_scipy is deprecated. Please replace it with:
#
# 	DGLGraph.adjacency_matrix(transpose, scipy_fmt="csr").
#
#   return warnings.warn(message, category=category, stacklevel=1)
# /scratch1/wang5386/py2021/lib/python3.7/site-packages/ipykernel_launcher.py:19: UserWarning: Casting complex values to real discards the imaginary part (Triggered internally at  /opt/conda/conda-bld/pytorch_1614378124864/work/aten/src/ATen/native/Copy.cpp:219.)

# %% [markdown]
# # Training: Set up model and train

# %%
import torch.nn.functional as F
from peg_conv import PEGConv
from torch import nn

# %%
class Net(torch.nn.Module):
    def __init__(self, in_feats_dim, hidden_dim):
        super(Net, self).__init__()
        
        self.in_feats_dim = in_feats_dim
        self.hidden_dim = hidden_dim

        self.conv1 = PEGConv(in_channels = in_feats_dim, out_channels = hidden_dim)
        self.conv2 = PEGConv(in_channels = hidden_dim, out_channels = hidden_dim)

    def forward(self, x, pos_encoding, edge_index):
        x = self.conv1(x, pos_encoding, edge_index)
        x = self.conv2(x, pos_encoding, edge_index)
        
        return F.log_softmax(x, dim=1)

# %%
model = Net(in_feats_dim = dataset.num_features, hidden_dim = 128)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)
criterion = torch.nn.CrossEntropyLoss()

model, data = model.to(device), data.to(device)
x = data.x
pos = torch.tensor(embeddings).to(device)
x = x.cuda(device)

# %%
def train():
    model.train()
    optimizer.zero_grad()
    output = model(x, pos, data.edge_index)
    loss = F.nll_loss(output[data.train_mask], data.y[data.train_mask])
    loss.backward()
    optimizer.step()

@torch.no_grad()
def test():
    model.eval()
    logits, accs = model(x, pos, data.edge_index), []
    for _, mask in data("train_mask", "val_mask", "test_mask"):
        pred = logits[mask].max(1)[1]
        acc = pred.eq(data.y[mask]).sum().item() / mask.sum().item()
        accs.append(acc)
    return accs

# %%
best_val_acc = test_acc = 0
for epoch in range(1, 201):
    train()
    train_acc, val_acc, tmp_test_acc = test()
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        test_acc = tmp_test_acc
    log = 'Epoch: {:03d}, Train: {:.4f}, Val: {:.4f}, Test: {:.4f}'
    print(log.format(epoch, train_acc, best_val_acc, test_acc))
# Out:
# Epoch: 001, Train: 0.3143, Val: 0.2180, Test: 0.1980
# Epoch: 002, Train: 0.4857, Val: 0.2860, Test: 0.2730
# Epoch: 003, Train: 0.5429, Val: 0.3040, Test: 0.3010
# Epoch: 004, Train: 0.5429, Val: 0.3040, Test: 0.3010
# Epoch: 005, Train: 0.4857, Val: 0.3040, Test: 0.3010
# Epoch: 006, Train: 0.4500, Val: 0.3040, Test: 0.3010
# Epoch: 007, Train: 0.4214, Val: 0.3040, Test: 0.3010
# Epoch: 008, Train: 0.3857, Val: 0.3040, Test: 0.3010
# Epoch: 009, Train: 0.3500, Val: 0.3040, Test: 0.3010
# Epoch: 010, Train: 0.3429, Val: 0.3040, Test: 0.3010
# Epoch: 011, Train: 0.3286, Val: 0.3040, Test: 0.3010
# Epoch: 012, Train: 0.3214, Val: 0.3040, Test: 0.3010
# Epoch: 013, Train: 0.3214, Val: 0.3040, Test: 0.3010
# Epoch: 014, Train: 0.3571, Val: 0.3040, Test: 0.3010
# Epoch: 015, Train: 0.5000, Val: 0.3040, Test: 0.3010
# Epoch: 016, Train: 0.6286, Val: 0.3720, Test: 0.3770
# Epoch: 017, Train: 0.5786, Val: 0.3720, Test: 0.3770
# Epoch: 018, Train: 0.4500, Val: 0.3720, Test: 0.3770
# Epoch: 019, Train: 0.4643, Val: 0.3720, Test: 0.3770
# Epoch: 020, Train: 0.5571, Val: 0.3720, Test: 0.3770
# Epoch: 021, Train: 0.7000, Val: 0.3720, Test: 0.3770
# Epoch: 022, Train: 0.8500, Val: 0.5380, Test: 0.5510
# Epoch: 023, Train: 0.9143, Val: 0.6620, Test: 0.6840
# Epoch: 024, Train: 0.9286, Val: 0.6640, Test: 0.7010
# Epoch: 025, Train: 0.9000, Val: 0.6640, Test: 0.7010
# Epoch: 026, Train: 0.9071, Val: 0.6640, Test: 0.7010
# Epoch: 027, Train: 0.9143, Val: 0.6680, Test: 0.6910
# Epoch: 028, Train: 0.9000, Val: 0.6700, Test: 0.6840
# Epoch: 029, Train: 0.8929, Val: 0.6700, Test: 0.6840
# Epoch: 030, Train: 0.9000, Val: 0.6900, Test: 0.6770
# Epoch: 031, Train: 0.9143, Val: 0.7160, Test: 0.7080
# Epoch: 032, Train: 0.9429, Val: 0.7400, Test: 0.7480
# Epoch: 033, Train: 0.9571, Val: 0.7640, Test: 0.7720
# Epoch: 034, Train: 0.9500, Val: 0.7740, Test: 0.7880
# Epoch: 035, Train: 0.9500, Val: 0.7760, Test: 0.7880
# Epoch: 036, Train: 0.9500, Val: 0.7760, Test: 0.7880
# Epoch: 037, Train: 0.9500, Val: 0.7760, Test: 0.7880
# Epoch: 038, Train: 0.9571, Val: 0.7760, Test: 0.7880
# Epoch: 039, Train: 0.9643, Val: 0.7760, Test: 0.7880
# Epoch: 040, Train: 0.9643, Val: 0.7760, Test: 0.7880
# Epoch: 041, Train: 0.9643, Val: 0.7760, Test: 0.7880
# Epoch: 042, Train: 0.9643, Val: 0.7800, Test: 0.8020
# Epoch: 043, Train: 0.9643, Val: 0.7800, Test: 0.8020
# Epoch: 044, Train: 0.9643, Val: 0.7840, Test: 0.8060
# Epoch: 045, Train: 0.9643, Val: 0.7860, Test: 0.8060
# Epoch: 046, Train: 0.9643, Val: 0.7880, Test: 0.8050
# Epoch: 047, Train: 0.9643, Val: 0.7880, Test: 0.8050
# Epoch: 048, Train: 0.9643, Val: 0.7880, Test: 0.8050
# Epoch: 049, Train: 0.9571, Val: 0.7880, Test: 0.8050
# Epoch: 050, Train: 0.9643, Val: 0.7880, Test: 0.8050
# Epoch: 051, Train: 0.9714, Val: 0.7880, Test: 0.8050
# Epoch: 052, Train: 0.9714, Val: 0.7880, Test: 0.8050
# Epoch: 053, Train: 0.9786, Val: 0.7880, Test: 0.8050
# Epoch: 054, Train: 0.9786, Val: 0.7920, Test: 0.8200
# Epoch: 055, Train: 0.9786, Val: 0.7940, Test: 0.8180
# Epoch: 056, Train: 0.9786, Val: 0.7940, Test: 0.8180
# Epoch: 057, Train: 0.9786, Val: 0.7940, Test: 0.8180
# Epoch: 058, Train: 0.9786, Val: 0.7940, Test: 0.8180
# Epoch: 059, Train: 0.9786, Val: 0.7940, Test: 0.8180
# Epoch: 060, Train: 0.9786, Val: 0.7980, Test: 0.8170
# Epoch: 061, Train: 0.9786, Val: 0.7980, Test: 0.8170
# Epoch: 062, Train: 0.9786, Val: 0.8000, Test: 0.8180
# Epoch: 063, Train: 0.9786, Val: 0.8000, Test: 0.8180
# Epoch: 064, Train: 0.9786, Val: 0.8000, Test: 0.8180
# Epoch: 065, Train: 0.9786, Val: 0.8000, Test: 0.8180
# Epoch: 066, Train: 0.9857, Val: 0.8000, Test: 0.8180
# Epoch: 067, Train: 0.9857, Val: 0.8000, Test: 0.8180
# Epoch: 068, Train: 0.9857, Val: 0.8000, Test: 0.8180
# Epoch: 069, Train: 0.9857, Val: 0.8000, Test: 0.8180
# Epoch: 070, Train: 0.9857, Val: 0.8000, Test: 0.8180
# Epoch: 071, Train: 0.9857, Val: 0.8000, Test: 0.8180
# Epoch: 072, Train: 0.9857, Val: 0.8000, Test: 0.8180
# Epoch: 073, Train: 0.9857, Val: 0.8000, Test: 0.8180
# Epoch: 074, Train: 0.9857, Val: 0.8000, Test: 0.8180
# Epoch: 075, Train: 0.9857, Val: 0.8000, Test: 0.8180
# Epoch: 076, Train: 0.9857, Val: 0.8000, Test: 0.8180
# Epoch: 077, Train: 0.9857, Val: 0.8000, Test: 0.8180
# Epoch: 078, Train: 0.9857, Val: 0.8000, Test: 0.8180
# Epoch: 079, Train: 0.9857, Val: 0.8000, Test: 0.8180
# Epoch: 080, Train: 0.9929, Val: 0.8000, Test: 0.8180
# Epoch: 081, Train: 0.9929, Val: 0.8000, Test: 0.8180
# Epoch: 082, Train: 0.9929, Val: 0.8000, Test: 0.8180
# Epoch: 083, Train: 0.9929, Val: 0.8000, Test: 0.8180
# Epoch: 084, Train: 0.9929, Val: 0.8000, Test: 0.8180
# Epoch: 085, Train: 0.9929, Val: 0.8000, Test: 0.8180
# Epoch: 086, Train: 0.9929, Val: 0.8000, Test: 0.8180
# Epoch: 087, Train: 0.9929, Val: 0.8000, Test: 0.8180
# Epoch: 088, Train: 0.9929, Val: 0.8000, Test: 0.8180
# Epoch: 089, Train: 0.9929, Val: 0.8000, Test: 0.8180
# Epoch: 090, Train: 0.9929, Val: 0.8000, Test: 0.8180
# Epoch: 091, Train: 0.9929, Val: 0.8000, Test: 0.8180
# Epoch: 092, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 093, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 094, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 095, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 096, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 097, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 098, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 099, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 100, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 101, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 102, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 103, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 104, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 105, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 106, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 107, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 108, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 109, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 110, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 111, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 112, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 113, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 114, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 115, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 116, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 117, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 118, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 119, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 120, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 121, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 122, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 123, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 124, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 125, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 126, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 127, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 128, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 129, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 130, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 131, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 132, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 133, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 134, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 135, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 136, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 137, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 138, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 139, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 140, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 141, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 142, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 143, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 144, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 145, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 146, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 147, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 148, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 149, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 150, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 151, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 152, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 153, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 154, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 155, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 156, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 157, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 158, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 159, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 160, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 161, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 162, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 163, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 164, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 165, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 166, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 167, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 168, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 169, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 170, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 171, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 172, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 173, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 174, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 175, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 176, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 177, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 178, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 179, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 180, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 181, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 182, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 183, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 184, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 185, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 186, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 187, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 188, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 189, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 190, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 191, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 192, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 193, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 194, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 195, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 196, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 197, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 198, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 199, Train: 1.0000, Val: 0.8000, Test: 0.8180
# Epoch: 200, Train: 1.0000, Val: 0.8000, Test: 0.8180
